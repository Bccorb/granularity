# %% [markdown]
# # Granularity
# This is a thought experirment for advanced discovery of related Earthdata events. The idea behind this project is that the metadata collected by NASA has extremely high value and the ability to search that data effiecently is pivotal to the discovery of relevant Earthdata information. With this project I sought out a bare bones example of how, given a few key features of a CMR Granule, one may be able to correlate data across collections, concepts, providers, and Natural events.
#
# Ideally this can be expanded in the furture to other features of a granule in the future.

# %%
# Imports
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from scipy.spatial.distance import directed_hausdorff
import numpy as np

import requests

pd.options.display.max_rows = 4000

# %% [markdown]
# ## Data collection pipeline

# %%
# Query to gather some collections to search through
response = requests.get("https://cmr.earthdata.nasa.gov/search/collections.json?has_granules=true&page_size=500")
json_result = response.json()

final_granules_list = []

# Obtain a list of concept ids
for item in json_result['feed']['entry']:
    # Obtain up to 25 granules from each collection id
    granules = requests.get(f"https://cmr.earthdata.nasa.gov/search/granules.json?collection_concept_id={item['id']}&page_size=25").json()

    for granule in granules['feed']['entry']:
        final_granules_list.append(granule)

len(final_granules_list)
# Out:
# 9883

# %%
final_granules_list[0]
# Out:
# {'time_start': '1984-12-25T00:00:00.000Z',
#  'updated': '2023-03-10T22:34:22.000Z',
#  'dataset_id': '15 Minute Stream Flow Data: USGS (FIFE)',
#  'points': ['39.1019 -96.595'],
#  'data_center': 'ORNL_DAAC',
#  'title': 'FIFE_STRM_15M.43601715.s15',
#  'coordinate_system': 'CARTESIAN',
#  'day_night_flag': 'BOTH',
#  'time_end': '1985-01-01T00:00:00.000Z',
#  'id': 'G2630004486-ORNL_DAAC',
#  'original_format': 'ECHO10',
#  'granule_size': '8.89E-4',
#  'browse_flag': False,
#  'collection_concept_id': 'C179003030-ORNL_DAAC',
#  'online_access_flag': True,
#  'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#    'title': 'Download 43601715.s15',
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/daacdata/fife/data/hydrolgy/strm_15m/y1984/43601715.s15'},
#   {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#    'title': "ORNL DAAC Data Set Documentation (USER'S GUIDE)",
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/FIFE/guides/15_min_strm_flow.html'},
#   {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#    'title': 'Data set Landing Page DOI URL (DATA SET LANDING PAGE)',
#    'hreflang': 'en-US',
#    'href': 'https://doi.org/10.3334/ORNLDAAC/1'},
#   {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#    'title': 'Data Set Documentation (GENERAL DOCUMENTATION)',
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/daacdata/fife/document/hydrolgy/15_min_strm_flow.pdf'},
#   {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#    'title': 'Data Set Documentation (GENERAL DOCUMENTATION)',
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/daacdata/fife/document/hydrolgy/strm_15m.doc'},
#   {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#    'title': 'Data Set Documentation (GENERAL DOCUMENTATION)',
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/daacdata/fife/data/hydrolgy/strm_15m/strm_15m.tdf'},
#   {'inherited': True,
#    'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/daacdata/fife/'},
#   {'inherited': True,
#    'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/FIFE/guides/15_min_strm_flow.html'},
#   {'inherited': True,
#    'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#    'hreflang': 'en-US',
#    'href': 'https://doi.org/10.3334/ORNLDAAC/1'},
#   {'inherited': True,
#    'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/daacdata/fife/document/hydrolgy/15_min_strm_flow.pdf'},
#   {'inherited': True,
#    'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/daacdata/fife/document/hydrolgy/strm_15m.doc'},
#   {'inherited': True,
#    'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#    'hreflang': 'en-US',
#    'href': 'https://daac.ornl.gov/daacdata/fife/data/hydrolgy/strm_15m/strm_15m.tdf'}]}

# %% [markdown]
# ## Data Analysis and Engineering

# %%
df = pd.json_normalize(final_granules_list)
df.head()
# Out:
#                  time_start                   updated  \
# 0  1984-12-25T00:00:00.000Z  2023-03-10T22:34:22.000Z
# 1  1985-01-01T00:00:00.000Z  2023-03-10T22:34:22.000Z
# 2  1985-02-01T00:00:00.000Z  2023-03-10T22:34:22.000Z
# 3  1985-03-01T00:00:00.000Z  2023-03-10T22:34:22.000Z
# 4  1985-04-01T00:00:00.000Z  2023-03-10T22:34:22.000Z
#
#                                 dataset_id             points data_center  \
# 0  15 Minute Stream Flow Data: USGS (FIFE)  [39.1019 -96.595]   ORNL_DAAC
# 1  15 Minute Stream Flow Data: USGS (FIFE)  [39.1019 -96.595]   ORNL_DAAC
# 2  15 Minute Stream Flow Data: USGS (FIFE)  [39.1019 -96.595]   ORNL_DAAC
# 3  15 Minute Stream Flow Data: USGS (FIFE)  [39.1019 -96.595]   ORNL_DAAC
# 4  15 Minute Stream Flow Data: USGS (FIFE)  [39.1019 -96.595]   ORNL_DAAC
#
#                         title coordinate_system day_night_flag  \
# 0  FIFE_STRM_15M.43601715.s15         CARTESIAN           BOTH
# 1  FIFE_STRM_15M.50011715.s15         CARTESIAN           BOTH
# 2  FIFE_STRM_15M.50321715.s15         CARTESIAN           BOTH
# 3  FIFE_STRM_15M.50601715.s15         CARTESIAN           BOTH
# 4  FIFE_STRM_15M.50911715.s15         CARTESIAN           BOTH
#
#                    time_end                     id  ... boxes  \
# 0  1985-01-01T00:00:00.000Z  G2630004486-ORNL_DAAC  ...   NaN
# 1  1985-02-01T00:00:00.000Z  G2630004452-ORNL_DAAC  ...   NaN
# 2  1985-03-01T00:00:00.000Z  G2630004461-ORNL_DAAC  ...   NaN
# 3  1985-04-01T00:00:00.000Z  G2630004485-ORNL_DAAC  ...   NaN
# 4  1985-05-01T00:00:00.000Z  G2630004469-ORNL_DAAC  ...   NaN
#
#   producer_granule_id  lines polygons  orbit_calculated_spatial_domains  \
# 0                 NaN    NaN      NaN                               NaN
# 1                 NaN    NaN      NaN                               NaN
# 2                 NaN    NaN      NaN                               NaN
# 3                 NaN    NaN      NaN                               NaN
# 4                 NaN    NaN      NaN                               NaN
#
#   orbit.ascending_crossing orbit.start_lat orbit.start_direction  \
# 0                      NaN             NaN                   NaN
# 1                      NaN             NaN                   NaN
# 2                      NaN             NaN                   NaN
# 3                      NaN             NaN                   NaN
# 4                      NaN             NaN                   NaN
#
#   orbit.end_lat orbit.end_direction
# 0           NaN                 NaN
# 1           NaN                 NaN
# 2           NaN                 NaN
# 3           NaN                 NaN
# 4           NaN                 NaN
#
# [5 rows x 26 columns]

# %%
# The features of a granule
df.columns
# Out:
# Index(['time_start', 'updated', 'dataset_id', 'points', 'data_center', 'title',
#        'coordinate_system', 'day_night_flag', 'time_end', 'id',
#        'original_format', 'granule_size', 'browse_flag',
#        'collection_concept_id', 'online_access_flag', 'links', 'boxes',
#        'producer_granule_id', 'lines', 'polygons',
#        'orbit_calculated_spatial_domains', 'orbit.ascending_crossing',
#        'orbit.start_lat', 'orbit.start_direction', 'orbit.end_lat',
#        'orbit.end_direction'],
#       dtype='object')

# %%
df.describe()
# Out:
#                       time_start                   updated  \
# count                       9883                      9883
# unique                      3745                      4589
# top     1984-01-01T00:00:00.000Z  2012-02-20T20:04:40.000Z
# freq                         142                        38
#
#                                      dataset_id             points  \
# count                                      9883                641
# unique                                      500                269
# top     15 Minute Stream Flow Data: USGS (FIFE)  [39.1019 -96.595]
# freq                                         25                 25
#
#        data_center                       title coordinate_system  \
# count         9883                        9883              9883
# unique          11                        9883                 4
# top     ORNL_CLOUD  FIFE_STRM_15M.43601715.s15         CARTESIAN
# freq          2726                           1              8334
#
#        day_night_flag                  time_end                     id  ...  \
# count            9883                      9883                   9883  ...
# unique              4                      4062                   9883  ...
# top       UNSPECIFIED  1989-10-31T00:00:00.000Z  G2630004486-ORNL_DAAC  ...
# freq             4398                       174                      1  ...
#
#                     boxes producer_granule_id  \
# count                6110                6148
# unique               1598                5938
# top     [-90 -180 90 180]     ALPSRP016350460
# freq                 1992                   5
#
#                                                 lines  \
# count                                             505
# unique                                            213
# top     [31.566639 -125.453053 37.649117 -116.897793]
# freq                                               33
#
#                                           polygons  \
# count                                         2552
# unique                                        1101
# top     [[25 -85 25 -58.5 50 -58.5 50 -85 25 -85]]
# freq                                            31
#
#        orbit_calculated_spatial_domains orbit.ascending_crossing  \
# count                               836                      300
# unique                              282                      144
# top            [{'orbit_number': '-1'}]                   -39.49
# freq                                236                        7
#
#        orbit.start_lat orbit.start_direction orbit.end_lat orbit.end_direction
# count              300                   300           300                 300
# unique               2                     2             2                   2
# top               81.8                     D         -81.8                   D
# freq               154                   154           154                 154
#
# [4 rows x 26 columns]

# %%
# make a copy of the df just in case! :) 
data = df
data = data.drop(['updated', 'time_start', 'time_end', 'dataset_id', 'browse_flag', 'online_access_flag', 'links', 'day_night_flag', 'original_format', 'coordinate_system', 'producer_granule_id', 'granule_size', 'orbit_calculated_spatial_domains', 'orbit.ascending_crossing', 'orbit.start_lat', 'orbit.start_direction', 'orbit.end_lat', 'orbit.end_direction', 'points', 'boxes', 'lines'], axis=1)
data = data[data.polygons.notna()]
data.head()
# Out:
#     data_center                      title                     id  \
# 340   NSIDC_ECS  SC:ABLVIS1B.001:129486296  G1513115240-NSIDC_ECS
# 341   NSIDC_ECS  SC:ABLVIS1B.001:129487317  G1513115837-NSIDC_ECS
# 342   NSIDC_ECS  SC:ABLVIS1B.001:129487360  G1513116253-NSIDC_ECS
# 343   NSIDC_ECS  SC:ABLVIS1B.001:129487358  G1513116276-NSIDC_ECS
# 344   NSIDC_ECS  SC:ABLVIS1B.001:129487523  G1513116588-NSIDC_ECS
#
#      collection_concept_id                                           polygons
# 340  C1513105920-NSIDC_ECS  [[52.73648 -107.21639 52.73287 -107.21639 52.7...
# 341  C1513105920-NSIDC_ECS  [[52.98734 -107.12686 52.98553 -107.12984 52.9...
# 342  C1513105920-NSIDC_ECS  [[53.29756 -107.55 53.29395 -107.55 53.28312 -...
# 343  C1513105920-NSIDC_ECS  [[53.31764 -108.09025 53.31764 -108.09327 53.3...
# 344  C1513105920-NSIDC_ECS  [[53.3285 -108.55822 53.32669 -108.55824 53.31...

# %%
data.describe()
# Out:
#        data_center                      title                     id  \
# count         2552                       2552                   2552
# unique           6                       2552                   2552
# top      LARC_ASDC  SC:ABLVIS1B.001:129486296  G1513115240-NSIDC_ECS
# freq          1184                          1                      1
#
#         collection_concept_id                                    polygons
# count                    2552                                        2552
# unique                    115                                        1101
# top     C1513105920-NSIDC_ECS  [[25 -85 25 -58.5 50 -58.5 50 -85 25 -85]]
# freq                       25                                          31

# %%
list(data['polygons'].head(1))
# Out:
# [[['52.73648 -107.21639 52.73287 -107.21639 52.72565 -107.21639 52.68955 -107.14518 52.6354 -107.03845 52.58847 -106.91991 52.54515 -106.83707 52.52349 -106.77785 52.54515 -106.77169 52.57764 -106.83084 52.61735 -106.93757 52.67511 -107.04424 52.71843 -107.1451 52.74009 -107.21639 52.73648 -107.21639']]]

# %%
def conversion_to_tuples(coord_list):
    coord_list = coord_list['polygons'][0][0].split()

    tuples = []
    for i in range(0, len(coord_list), 2):
        tuples.append((float(coord_list[i]), float(coord_list[i + 1])))

    return tuples

# Testing the function works
conversion_to_tuples(data.iloc[0])
# Out:
# [(52.73648, -107.21639),
#  (52.73287, -107.21639),
#  (52.72565, -107.21639),
#  (52.68955, -107.14518),
#  (52.6354, -107.03845),
#  (52.58847, -106.91991),
#  (52.54515, -106.83707),
#  (52.52349, -106.77785),
#  (52.54515, -106.77169),
#  (52.57764, -106.83084),
#  (52.61735, -106.93757),
#  (52.67511, -107.04424),
#  (52.71843, -107.1451),
#  (52.74009, -107.21639),
#  (52.73648, -107.21639)]

# %%
# Convert every row to tuples
for index, row in data.iterrows():
    row['polygons'] = conversion_to_tuples(row)
    data.at[index,'polygons'] = row['polygons']
data.head()
# Out:
#     data_center                      title                     id  \
# 340   NSIDC_ECS  SC:ABLVIS1B.001:129486296  G1513115240-NSIDC_ECS
# 341   NSIDC_ECS  SC:ABLVIS1B.001:129487317  G1513115837-NSIDC_ECS
# 342   NSIDC_ECS  SC:ABLVIS1B.001:129487360  G1513116253-NSIDC_ECS
# 343   NSIDC_ECS  SC:ABLVIS1B.001:129487358  G1513116276-NSIDC_ECS
# 344   NSIDC_ECS  SC:ABLVIS1B.001:129487523  G1513116588-NSIDC_ECS
#
#      collection_concept_id                                           polygons
# 340  C1513105920-NSIDC_ECS  [(52.73648, -107.21639), (52.73287, -107.21639...
# 341  C1513105920-NSIDC_ECS  [(52.98734, -107.12686), (52.98553, -107.12984...
# 342  C1513105920-NSIDC_ECS  [(53.29756, -107.55), (53.29395, -107.55), (53...
# 343  C1513105920-NSIDC_ECS  [(53.31764, -108.09025), (53.31764, -108.09327...
# 344  C1513105920-NSIDC_ECS  [(53.3285, -108.55822), (53.32669, -108.55824)...

# %% [markdown]
# ## (Failed attempts at ) Training a Machine Learning Model

# %%
# Hold out data
test_data = data.tail(10)

data.drop(data.tail(10).index, inplace = True)

X = np.concatenate(data['polygons'].values)

k = 5
model = NearestNeighbors(n_neighbors=k, metric='euclidean')
model.fit(X)
# Out:
# NearestNeighbors(metric='euclidean')

# %% [markdown]
# ## Hausdorff_distance Approach

# %%
def find_similar_shapes(query_shape, data, top_n=5):
    similarities = []
    for shape in data['polygons']:
        similarity = directed_hausdorff(query_shape, shape)[0]

        similarities.append(similarity)

    similar_indices = sorted(range(len(similarities)), key=lambda i: similarities[i])[:top_n]
    similar_shapes = data.iloc[similar_indices]

    return similar_shapes

# %%
test_data.iloc[0]
# Out:
# data_center                                                        OB_DAAC
# title                    1_MODISA_L1_GEO_AQUA_MODIS.20020704T011501.GEO...
# id                                                     G2527713500-OB_DAAC
# collection_concept_id                                  C2526537408-OB_DAAC
# polygons                 [(64.2215, -168.93315), (58.13617, 148.42354),...
# Name: 9848, dtype: object

# %%
test_data.iloc[0].title
# Out:
# '1_MODISA_L1_GEO_AQUA_MODIS.20020704T011501.GEO.hdf'

# %%
similar_granules = find_similar_shapes(test_data.iloc[0].polygons, data)
similar_granules
# Out:
#      data_center                      title                     id  \
# 9097   NSIDC_ECS     SC:AA_L2A.001:29262271  G1241441498-NSIDC_ECS
# 8162   NSIDC_ECS   SC:AU_Land.001:142373337  G1570336335-NSIDC_ECS
# 8120   NSIDC_ECS  SC:AU_Ocean.001:276148003  G2716487483-NSIDC_ECS
# 8145   NSIDC_ECS   SC:AU_Rain.001:254894218  G2552253056-NSIDC_ECS
# 8554   NSIDC_ECS   SC:AMSREL1A.003:41185207   G187453387-NSIDC_ECS
#
#       collection_concept_id                                           polygons
# 9097  C1241435536-NSIDC_ECS  [(-80.13003204789746, 8.045044113989507), (-81...
# 8162  C1343001245-NSIDC_ECS  [(-81.90328868494649, 8.572944224512066), (-79...
# 8120  C2176472016-NSIDC_ECS  [(-82.31548700871022, 12.414641603010141), (-7...
# 8145  C1708620364-NSIDC_ECS  [(-82.31548700871022, 12.414641603010141), (-7...
# 8554   C186584407-NSIDC_ECS  [(72.89720139676162, -79.30297860712726), (72....

# %% [markdown]
# ## Lessons learned
#
# - I don't know how to numerically represent a set of coordinates such that a good ML model like ball and tree or KNN could be best utilized
# - I learned a good bit about hausdorff distance and I think this could be improved on to make the shape recommendations closer
# - I would have loved to map this to more features of a granule and in the future that would be intresting
# - Math is really hard
